# %% [markdown]
# # GPU mode lecture 002 - connectivity check
#
# Run the cells below to confirm that this notebook is using the remote GPU server.

# %%
import platform
import sys

print(f"Python: {sys.version.split()[0]}")
print(f"Platform: {platform.platform()}")
# Out:
# Python: 3.10.12
# Platform: Linux-6.8.0-1066-gcp-x86_64-with-glibc2.35

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)
# Out:
# CUDA available: True
# GPU: NVIDIA L4
# CUDA version: 12.5

# %%
from pathlib import Path

workspace = Path.cwd()
print("Working directory:", workspace)
print("Notebook directory exists:", Path('/workspace/infra/home/connectivity-test.ipynb').is_file())
# Out:
# Working directory: /workspace
# Notebook directory exists: True
